# %% [markdown]
# # First thing to do, make a copy of this notebook under File->Make a Copy with some intelligent naming convention.
#
# ---

# %% [markdown]
# # Set your observing times here.
#
# ## NB: This will be a broader window that you'll actually use. The final output will give you orbit-by-orbit pointing information. So you can use a subset of the orbits that are chosen here.

# %%
from datetime import datetime

# Note that tstart and tend should span for at least one day because of the way the scripts are written.
tstart = '2018-01-12T00:00:00'
tend = '2018-01-13T00:00:00'

ttarget = '2018-01-12T21:54:00'
# Turn these into datetime objects

tstart = datetime.strptime(tstart, '%Y-%m-%dT%H:%M:%S')
tend = datetime.strptime(tend, '%Y-%m-%dT%H:%M:%S')
ttarget = datetime.strptime(ttarget,'%Y-%m-%dT%H:%M:%S')

# %% [markdown]
# ---
# # Step 1, get the nominal RA/Dec Position for the Moon at the nominal target time
#
# ## We use this to determine what the occultation times are.

# %%
from skyfield.api import Loader
from astropy.time import Time
import astropy.units as u

load = Loader('../../data')

ts = load.timescale()
planets = load('de436.bsp')

astro_time = Time(ttarget)
t = ts.from_astropy(astro_time)
moon, earth = planets['moon'], planets['earth']
astrometric = earth.at(t).observe(moon)
ra, dec, distance = astrometric.radec()


occstring = "./occ {0:0.4f} {1:0.4f} Latest_TLE.txt {2}:{3:03d}:00:00:00 {4}:{5:03d}:00:00:00 lunar_{3}_{5}.occ".format(
      ra.to(u.deg).value, dec.to(u.deg).value,
      tstart.timetuple().tm_year, tstart.timetuple().tm_yday, 
      tend.timetuple().tm_year, tend.timetuple().tm_yday)


outfile = '../orbit_engine/lunar_{0}to{1}.sh'.format(tstart.timetuple().tm_yday, tend.timetuple().tm_yday)
print(outfile)

f = open(outfile, 'w')
f.write(occstring)
f.close()


import os
import stat

st = os.stat(outfile)
os.chmod(outfile, st.st_mode | stat.S_IEXEC)
# Out:
# ../orbit_engine/lunar_12to13.sh

# %% [markdown]
# ---
# # Step 2, get the PA position
#
# ## We use this to figure out how to offset the FoV for the Moon

# %%
pastring = "./att2pa {0} {1} {2} -5 > lunar_{3}_{4}.pa".format(
    ttarget.strftime('%Y:%j:%H:%M:%S'),
    ra.to(u.deg).value, dec.to(u.deg).value,
    tstart.timetuple().tm_yday, tend.timetuple().tm_yday)
outfile = '../orbit_engine/lunar_{0}to{1}_pa.sh'.format(tstart.timetuple().tm_yday, tend.timetuple().tm_yday)
print(outfile)

f = open(outfile, 'w')
f.write(pastring)
f.close()


import os
import stat

st = os.stat(outfile)
os.chmod(outfile, st.st_mode | stat.S_IEXEC)
# Out:
# ../orbit_engine/lunar_12to13_pa.sh

# %% [markdown]
# ---
# # Step 2: Go run the code that figures out the unocculted periods for the RA/Dec and the date range reported above.
#
# This works on lif. There are example shell scripts in the ../orbit_engine directory that use the version that Karl already compiled for the nuops users.
#
# First, get the latest TLE archive:
#
# `./get_latest_TLE.sh`
#
# Run the script that was produced to produce the occultation files:
#
# `./lunar_225to226.sh`
#
# ...and the one to get the PA position. **Remember that this is the MPS PA angle, so the SKY PA = 180 - MPA_PA. However, the code in nsutar_planning.io knows how to fix this and will return SKY PA values.**
#
# `./lunar_225to226_pa.sh`
#
# Check in the resulting output files in to github if you're working remotely.
#
# `git add lunar_225to226.occ lunar_225to226.pa`
#
# `git commit -m "Files for days 225-226"`
#
# `git push`
#
# Then pull this down to your local environment and continue below.

# %% [markdown]
# # Step 3: Initialize your libraries and parse the resulting occultation file:

# %%
from nustar_planning import io
occfile= "../orbit_engine/lunar_{0}_{1}.occ".format(tstart.timetuple().tm_yday,tend.timetuple().tm_yday )
pafile= "../orbit_engine/lunar_{0}_{1}.pa".format(tstart.timetuple().tm_yday,tend.timetuple().tm_yday )

orbits = io.parse_occ(occfile)
sky_pa = io.parse_pa(pafile)


# NB: The "head" command here only shows the first couple of rows. Do a "print(orbits)" to see them all.
orbits.head()
print('SKY PA angle: ', sky_pa)
# Out:
# SKY PA angle:  169.081036

# %% [markdown]
# # Use SkyField to get the location of the Moon for each orbit:
#
# This puts the output into the provided text file. This shows the *aim* time that was used to determine the pointing. You should slew while the source is occulted.

# %%
# Sanity check. Use this block to figure out which orbit(s) in the occultation file you want to use

import nustar_planning.lunar_planning as lunar_planning
sub = orbits.iloc[13:14].reset_index()
lunar_planning.position(sub, steps = 5, parallax_correction=True, load_path ='../../data')
# Out:
# [#################################] 100% deltat.data
# [#################################] 100% deltat.preds
# [#################################] 100% Leap_Second.dat
# Aim Time            RA         Dec
# 2018-01-12T21:54:50 247.14584  -16.53040
# 2018-01-12T22:06:04.600000 247.20126  -16.77901
# 2018-01-12T22:17:19.200000 246.77066  -17.00762
# 2018-01-12T22:28:33.800000 246.12055  -17.10179
# 2018-01-12T22:39:48.400000 245.64664  -17.02018

# %%
# PA == sky_pa from above, Rmoon = 940 arcseconds (default), 6 arcminutes maximum drift (default) and
# no minimum dwell period (default)

# Note, this takes a few minutes to run!

outfile = 'lunar_{0}_{1}_pointing_v3.txt'.format(tstart.timetuple().tm_yday,tend.timetuple().tm_yday )

lunar_planning.position_shift(sub, parallax_correction=True, pa = sky_pa*u.deg, dt = 3*u.s, min_shift=3*u.arcmin,
                              outfile=outfile, load_path ='../../data', diag=True)
print("Output is stored in: {}".format(outfile))
# Out:
# Start of dwell: 2018-01-12T21:49:50
# End of dwell: 2018-01-12T21:50:56
#
# Time used to aim: 2018-01-12T21:50:23
# Dwell Duration (sec): 66.00
#   Dwell Drift (arcmin): 3.04
#
# Start of dwell: 2018-01-12T21:50:56
# End of dwell: 2018-01-12T21:52:08
#
# Time used to aim: 2018-01-12T21:51:32
# Dwell Duration (sec): 72.00
#   Dwell Drift (arcmin): 3.09
#
# Start of dwell: 2018-01-12T21:52:08
# End of dwell: 2018-01-12T21:53:26
#
# Time used to aim: 2018-01-12T21:52:47
# Dwell Duration (sec): 78.00
#   Dwell Drift (arcmin): 3.07
#
# Start of dwell: 2018-01-12T21:53:26
# End of dwell: 2018-01-12T21:54:53
#
# Time used to aim: 2018-01-12T21:54:09.500000
# Dwell Duration (sec): 87.00
#   Dwell Drift (arcmin): 3.08
#
# Start of dwell: 2018-01-12T21:54:53
# End of dwell: 2018-01-12T21:56:29
#
# Time used to aim: 2018-01-12T21:55:41
# Dwell Duration (sec): 96.00
#   Dwell Drift (arcmin): 3.00
#
# Start of dwell: 2018-01-12T21:56:29
# End of dwell: 2018-01-12T21:58:20
#
# Time used to aim: 2018-01-12T21:57:24.500000
# Dwell Duration (sec): 111.00
#   Dwell Drift (arcmin): 3.02
#
# Start of dwell: 2018-01-12T21:58:20
# End of dwell: 2018-01-12T22:00:26
#
# Time used to aim: 2018-01-12T21:59:23
# Dwell Duration (sec): 126.00
#   Dwell Drift (arcmin): 3.02
#
# Start of dwell: 2018-01-12T22:00:26
# End of dwell: 2018-01-12T22:02:38
#
# Time used to aim: 2018-01-12T22:01:32
# Dwell Duration (sec): 132.00
#   Dwell Drift (arcmin): 3.02
#
# Start of dwell: 2018-01-12T22:02:38
# End of dwell: 2018-01-12T22:04:41
#
# Time used to aim: 2018-01-12T22:03:39.500000
# Dwell Duration (sec): 123.00
#   Dwell Drift (arcmin): 3.04
#
# Start of dwell: 2018-01-12T22:04:41
# End of dwell: 2018-01-12T22:06:29
#
# Time used to aim: 2018-01-12T22:05:35
# Dwell Duration (sec): 108.00
#   Dwell Drift (arcmin): 3.05
#
# Start of dwell: 2018-01-12T22:06:29
# End of dwell: 2018-01-12T22:08:05
#
# Time used to aim: 2018-01-12T22:07:17
# Dwell Duration (sec): 96.00
#   Dwell Drift (arcmin): 3.09
#
# Start of dwell: 2018-01-12T22:08:05
# End of dwell: 2018-01-12T22:09:29
#
# Time used to aim: 2018-01-12T22:08:47
# Dwell Duration (sec): 84.00
#   Dwell Drift (arcmin): 3.01
#
# Start of dwell: 2018-01-12T22:09:29
# End of dwell: 2018-01-12T22:10:47
#
# Time used to aim: 2018-01-12T22:10:08
# Dwell Duration (sec): 78.00
#   Dwell Drift (arcmin): 3.06
#
# Start of dwell: 2018-01-12T22:10:47
# End of dwell: 2018-01-12T22:11:59
#
# Time used to aim: 2018-01-12T22:11:23
# Dwell Duration (sec): 72.00
#   Dwell Drift (arcmin): 3.04
#
# Start of dwell: 2018-01-12T22:11:59
# End of dwell: 2018-01-12T22:13:08
#
# Time used to aim: 2018-01-12T22:12:33.500000
# Dwell Duration (sec): 69.00
#   Dwell Drift (arcmin): 3.10
#
# Start of dwell: 2018-01-12T22:13:08
# End of dwell: 2018-01-12T22:14:14
#
# Time used to aim: 2018-01-12T22:13:41
# Dwell Duration (sec): 66.00
#   Dwell Drift (arcmin): 3.13
#
# Start of dwell: 2018-01-12T22:14:14
# End of dwell: 2018-01-12T22:15:17
#
# Time used to aim: 2018-01-12T22:14:45.500000
# Dwell Duration (sec): 63.00
#   Dwell Drift (arcmin): 3.12
#
# Start of dwell: 2018-01-12T22:15:17
# End of dwell: 2018-01-12T22:16:17
#
# Time used to aim: 2018-01-12T22:15:47
# Dwell Duration (sec): 60.00
#   Dwell Drift (arcmin): 3.08
#
# Start of dwell: 2018-01-12T22:16:17
# End of dwell: 2018-01-12T22:17:14
#
# Time used to aim: 2018-01-12T22:16:45.500000
# Dwell Duration (sec): 57.00
#   Dwell Drift (arcmin): 3.01
#
# Start of dwell: 2018-01-12T22:17:14
# End of dwell: 2018-01-12T22:18:11
#
# Time used to aim: 2018-01-12T22:17:42.500000
# Dwell Duration (sec): 57.00
#   Dwell Drift (arcmin): 3.08
#
# Start of dwell: 2018-01-12T22:18:11
# End of dwell: 2018-01-12T22:19:08
#
# Time used to aim: 2018-01-12T22:18:39.500000
# Dwell Duration (sec): 57.00
#   Dwell Drift (arcmin): 3.15
#
# Start of dwell: 2018-01-12T22:19:08
# End of dwell: 2018-01-12T22:20:02
#
# Time used to aim: 2018-01-12T22:19:35
# Dwell Duration (sec): 54.00
#   Dwell Drift (arcmin): 3.03
#
# Start of dwell: 2018-01-12T22:20:02
# End of dwell: 2018-01-12T22:20:56
#
# Time used to aim: 2018-01-12T22:20:29
# Dwell Duration (sec): 54.00
#   Dwell Drift (arcmin): 3.06
#
# Start of dwell: 2018-01-12T22:20:56
# End of dwell: 2018-01-12T22:21:50
#
# Time used to aim: 2018-01-12T22:21:23
# Dwell Duration (sec): 54.00
#   Dwell Drift (arcmin): 3.09
#
# Start of dwell: 2018-01-12T22:21:50
# End of dwell: 2018-01-12T22:22:44
#
# Time used to aim: 2018-01-12T22:22:17
# Dwell Duration (sec): 54.00
#   Dwell Drift (arcmin): 3.10
#
# Start of dwell: 2018-01-12T22:22:44
# End of dwell: 2018-01-12T22:23:38
#
# Time used to aim: 2018-01-12T22:23:11
# Dwell Duration (sec): 54.00
#   Dwell Drift (arcmin): 3.10
#
# Start of dwell: 2018-01-12T22:23:38
# End of dwell: 2018-01-12T22:24:32
#
# Time used to aim: 2018-01-12T22:24:05
# Dwell Duration (sec): 54.00
#   Dwell Drift (arcmin): 3.09
#
# Start of dwell: 2018-01-12T22:24:32
# End of dwell: 2018-01-12T22:25:26
#
# Time used to aim: 2018-01-12T22:24:59
# Dwell Duration (sec): 54.00
#   Dwell Drift (arcmin): 3.07
#
# Start of dwell: 2018-01-12T22:25:26
# End of dwell: 2018-01-12T22:26:20
#
# Time used to aim: 2018-01-12T22:25:53
# Dwell Duration (sec): 54.00
#   Dwell Drift (arcmin): 3.04
#
# Start of dwell: 2018-01-12T22:26:20
# End of dwell: 2018-01-12T22:27:17
#
# Time used to aim: 2018-01-12T22:26:48.500000
# Dwell Duration (sec): 57.00
#   Dwell Drift (arcmin): 3.16
#
# Start of dwell: 2018-01-12T22:27:17
# End of dwell: 2018-01-12T22:28:14
#
# Time used to aim: 2018-01-12T22:27:45.500000
# Dwell Duration (sec): 57.00
#   Dwell Drift (arcmin): 3.10
#
# Start of dwell: 2018-01-12T22:28:14
# End of dwell: 2018-01-12T22:29:11
#
# Time used to aim: 2018-01-12T22:28:42.500000
# Dwell Duration (sec): 57.00
#   Dwell Drift (arcmin): 3.03
#
# Start of dwell: 2018-01-12T22:29:11
# End of dwell: 2018-01-12T22:30:11
#
# Time used to aim: 2018-01-12T22:29:41
# Dwell Duration (sec): 60.00
#   Dwell Drift (arcmin): 3.09
#
# Start of dwell: 2018-01-12T22:30:11
# End of dwell: 2018-01-12T22:31:14
#
# Time used to aim: 2018-01-12T22:30:42.500000
# Dwell Duration (sec): 63.00
#   Dwell Drift (arcmin): 3.13
#
# Start of dwell: 2018-01-12T22:31:14
# End of dwell: 2018-01-12T22:32:17
#
# Time used to aim: 2018-01-12T22:31:45.500000
# Dwell Duration (sec): 63.00
#   Dwell Drift (arcmin): 3.00
#
# Start of dwell: 2018-01-12T22:32:17
# End of dwell: 2018-01-12T22:33:26
#
# Time used to aim: 2018-01-12T22:32:51.500000
# Dwell Duration (sec): 69.00
#   Dwell Drift (arcmin): 3.12
#
# Start of dwell: 2018-01-12T22:33:26
# End of dwell: 2018-01-12T22:34:38
#
# Time used to aim: 2018-01-12T22:34:02
# Dwell Duration (sec): 72.00
#   Dwell Drift (arcmin): 3.06
#
# Start of dwell: 2018-01-12T22:34:38
# End of dwell: 2018-01-12T22:35:56
#
# Time used to aim: 2018-01-12T22:35:17
# Dwell Duration (sec): 78.00
#   Dwell Drift (arcmin): 3.06
#
# Start of dwell: 2018-01-12T22:35:56
# End of dwell: 2018-01-12T22:37:23
#
# Time used to aim: 2018-01-12T22:36:39.500000
# Dwell Duration (sec): 87.00
#   Dwell Drift (arcmin): 3.09
#
# Start of dwell: 2018-01-12T22:37:23
# End of dwell: 2018-01-12T22:38:59
#
# Time used to aim: 2018-01-12T22:38:11
# Dwell Duration (sec): 96.00
#   Dwell Drift (arcmin): 3.00
#
# Start of dwell: 2018-01-12T22:38:59
# End of dwell: 2018-01-12T22:40:53
#
# Time used to aim: 2018-01-12T22:39:56
# Dwell Duration (sec): 114.00
#   Dwell Drift (arcmin): 3.02
#
# Start of dwell: 2018-01-12T22:40:53
# End of dwell: 2018-01-12T22:43:14
#
# Time used to aim: 2018-01-12T22:42:03.500000
# Dwell Duration (sec): 141.00
#   Dwell Drift (arcmin): 3.02
#
# Start of dwell: 2018-01-12T22:43:14
# End of dwell: 2018-01-12T22:45:59
#
# Time used to aim: 2018-01-12T22:44:36.500000
# Dwell Duration (sec): 165.00
#   Dwell Drift (arcmin): 3.00
#
# Start of dwell: 2018-01-12T22:45:59
# End of dwell: 2018-01-12T22:48:29
#
# Time used to aim: 2018-01-12T22:47:14
# Dwell Duration (sec): 150.00
#   Dwell Drift (arcmin): 3.05
#
# Start of dwell: 2018-01-12T22:48:29
# End of dwell: 2018-01-12T22:50:29
#
# Time used to aim: 2018-01-12T22:49:29
# Dwell Duration (sec): 120.00
#   Dwell Drift (arcmin): 3.06
#
# Start of dwell: 2018-01-12T22:50:29
# End of dwell: 2018-01-12T22:52:08
#
# Time used to aim: 2018-01-12T22:51:18.500000
# Dwell Duration (sec): 99.00
#   Dwell Drift (arcmin): 3.05
#
# Start of dwell: 2018-01-12T22:52:08
# End of dwell: 2018-01-12T22:53:35
#
# Time used to aim: 2018-01-12T22:52:51.500000
# Dwell Duration (sec): 87.00
#   Dwell Drift (arcmin): 3.10
#
# Start of dwell: 2018-01-12T22:53:35
# End of dwell: 2018-01-12T22:54:53
#
# Time used to aim: 2018-01-12T22:54:14
# Dwell Duration (sec): 78.00
#   Dwell Drift (arcmin): 3.11
#
# Output is stored in: lunar_12_13_pointing_v3.txt
